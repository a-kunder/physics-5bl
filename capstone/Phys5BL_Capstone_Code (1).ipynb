# %%
import numpy as np
import math
import scipy.optimize as opt
from scipy.interpolate import interp1d
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Data:

file = open('LongData.csv', 'r')
#print(file.read())

x,y= np.loadtxt('LongData.csv', delimiter=",", skiprows=1, usecols=(0,1), unpack=True)
#frequency = np.array(Frequency)
#Vo = np.array(Vo)
#Vc = np.array(Vc)
#phase = np.array(Phase)*3.1415/180
start = 1000
x = x[1000:]
y = y[1000:]

x = np.array(x)
y = np.array(y)

x = x - np.mean(x)
y = y - np.mean(y)

ratio = np.divide(x,y)
angle = np.arctan2(x,y)

#plt.plot(x)
#plt.plot(y)
#plt.plot(angle)

def moving_average(x, w):
    return np.convolve(x, np.ones(w), 'valid') / w

der_angle = np.diff(angle.reshape(-1, 2), axis=1).ravel()
der_angle[der_angle > .5] = 0
der_angle[der_angle < -.5] = 0
#der_angle = np.diff(angle)

plt.plot(moving_average(der_angle,40))



#b1_time,b1_a1,b1_a2= np.loadtxt('Phys5BL_Exp10_Data/Experiment1bSetup1.csv', delimiter=",", skiprows=1, usecols=(0,1,2), unpack=True)
#plt.plot(b1_a2)
#b1_start = 7880
#b1_stop = 9000
#plt.plot(b1_a2[b1_start:b1_stop])

#b2_time,b2_a1,b2_a2= np.loadtxt('Phys5BL_Exp10_Data/Experiment1bSetup2.csv', delimiter=",", skiprows=1, usecols=(0,1,2), unpack=True)
#b2_start = 13100
#b2_stop = 15800
#plt.plot(b2_a2[b2_start:b2_stop])

#c_time,c_a1,c_a2= np.loadtxt('Phys5BL_Exp10_Data/Experiment1c.csv', delimiter=",", skiprows=1, usecols=(0,1,2), unpack=True)
#c_start = 32220
#c_stop = 33000
#plt.plot(c_a2[c_start:c_stop])
#len(c_time[c_start:c_stop])

# %%
plt.plot(x,y)
plt.axes().set_aspect('equal')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
def linear_fit(d,m,b):
    return m*d + b
def damped_oscillator(t,a,d,w,p,b):
    return a*np.exp(-d*t) * np.cos(w*t - p) + b

# %%
# Fits to the nonlinear function

# Choose the model you wish to fit to: simple_y, simple_a, vdamped_y, vdamped_a
#oscillator_model = vdamped_a
oscillator_model=damped_oscillator


# Initial guess values of fit parameters
    # If using simple_a or simple_y:  [A, B, w, phi]
    # If using vdamped_a or vdamped_y: [ A, B, w, phi, beta]

Ainit, Dinit, Winit, Pinit, Binit=[1, 1, 1, 1, 1]
yvals = np.array(moving_average(der_angle,40))
tvals = np.array(range(0,len(yvals)))*(1/30)
start_pars=[Ainit, Dinit, Winit, Pinit, Binit]
#pars, cov = opt.curve_fit(oscillator_model, tvals-start_time, yvals, p0=start_pars, betainit)
pars, cov = opt.curve_fit(oscillator_model, tvals, yvals, p0=start_pars, maxfev = 10000)

[A, D, W, P, B] = pars
#[A, B, w, phi, beta] = pars
std_errs = np.sqrt(np.diag(cov))



start_time = 0

# Graph
#plt.plot(tvals-start_time, oscillator_model(tvals-start_time, Ainit, Binit, winit, phiinit, betainit), color='orange')
plt.plot(tvals, oscillator_model(tvals-start_time, A, D, W, P, B), color='orange')
plt.scatter(tvals, yvals)
plt.show()
# Out:
# array(['3', '3.012', 'yo'], dtype='<U32')

# %%
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!
#CELLS BELOW THIS POINT IRRELEVANT!!

# %%
plt.plot(fallingTime,fallingRatio,'b',marker='o')
plt.ylabel("Log(Vc/Vo)")
plt.xlabel("Log(Angular frequency)")
plt.title("Vc/Vo vs Angular Frequency, loglog plot")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-4f1155235c50> in <module>
# ----> 1 plt.plot(fallingTime,fallingRatio,'b',marker='o')
#       2 plt.ylabel("Log(Vc/Vo)")
#       3 plt.xlabel("Log(Angular frequency)")
#       4 plt.title("Vc/Vo vs Angular Frequency, loglog plot")
#
# NameError: name 'fallingTime' is not defined

# %%
# Simple harmonic motion using acceleration
def given_fit(t, A, B):                  # inputs: t:time, A:amplitude, B:offset, w:angular frequency, phi:phase
    return A*np.exp(-t/B)   # output: acceleration

start_pars=[1,1.5*10**(-3)]
#pars, cov = opt.curve_fit(oscillator_model, tvals-start_time, yvals, p0=start_pars, betainit)

# %%
pars, cov = opt.curve_fit(given_fit, fallingTime, fallingRatio, p0=start_pars)

A,B = pars
ypred = given_fit(fallingTime, A, B)
#ymanual = given_fit(angular_frequency, 0.99688, .00158)
# amplitude = .99688, RC = .00158 -- values from Ronnie's fit
print(B)
print(A)

plt.plot(fallingTime,fallingRatio,'b',marker='x',ms=5,label = "Data")
plt.plot(fallingTime,ypred,'r',marker='.',ms=1,label = "Least squares fit A*np.exp(-t/B)")
plt.ylabel("Vc/Vo ratio")
plt.xlabel("Time since start of discharge (seconds)")
plt.title("Exp 1a: RC circuit discharging curve - Normalized voltage over time")
#plt.loglog(angular_frequency,ymanual,'g')
plt.text(1,.5,"Fit parameters")
plt.text(1,.4,"A = %.4g" %(A))
plt.text(1,.3,"B = %.4g" %(B))
plt.legend()
# Out:
# 0.600505750100247
# 0.9972175111456448

# %%
pars, cov = opt.curve_fit(given_fit, b1_fallingTime, b1_fallingRatio, p0=start_pars)

A,B = pars
ypred = given_fit(b1_fallingTime, A, B)
#ymanual = given_fit(angular_frequency, 0.99688, .00158)
# amplitude = .99688, RC = .00158 -- values from Ronnie's fit
print(B)
print(A)

plt.plot(b1_fallingTime,b1_fallingRatio,'b',marker='x',ms=5,label = "Data")
plt.plot(b1_fallingTime,ypred,'r',marker='.',ms=1,label = "Least squares fit A*np.exp(-t/B)")
plt.ylabel("Vc/Vo ratio")
plt.xlabel("Time since start of discharge (seconds)")
plt.title("Exp 1b setup 1: RC circuit discharging curve - Normalized voltage over time")
#plt.loglog(angular_frequency,ymanual,'g')
plt.text(1,.5,"Fit parameters")
plt.text(1,.4,"A = %.4g" %(A))
plt.text(1,.3,"B = %.4g" %(B))
plt.legend()
# Out:
# 0.2970335789775284
# 0.992899371169556

# %%
pars, cov = opt.curve_fit(given_fit, b2_fallingTime, b2_fallingRatio, p0=start_pars)

A,B = pars
ypred = given_fit(b2_fallingTime, A, B)
#ymanual = given_fit(angular_frequency, 0.99688, .00158)
# amplitude = .99688, RC = .00158 -- values from Ronnie's fit
print(B)
print(A)

plt.plot(b2_fallingTime,b2_fallingRatio,'b',marker='x',ms=5,label = "Data")
plt.plot(b2_fallingTime,ypred,'r',marker='.',ms=1,label = "Least squares fit A*np.exp(-t/B)")
plt.ylabel("Vc/Vo ratio")
plt.xlabel("Time since start of discharge (seconds)")
plt.title("Exp 1b setup 2: RC circuit discharging curve - Normalized voltage over time")
#plt.loglog(angular_frequency,ymanual,'g')
plt.text(1,.5,"Fit parameters")
plt.text(1,.4,"A = %.4g" %(A))
plt.text(1,.3,"B = %.4g" %(B))
plt.legend()
# Out:
# 0.17422894341363082
# 0.9909594925774048

# %%
pars, cov = opt.curve_fit(given_fit, c_fallingTime, c_fallingRatio, p0=start_pars)

A,B = pars
ypred = given_fit(c_fallingTime, A, B)
#ymanual = given_fit(angular_frequency, 0.99688, .00158)
# amplitude = .99688, RC = .00158 -- values from Ronnie's fit
print(B)
print(A)

plt.plot(c_fallingTime,c_fallingRatio,'b',marker='x',ms=5,label = "Data")
plt.plot(c_fallingTime,ypred,'r',marker='.',ms=1,label = "Least squares fit A*np.exp(-t/B)")
plt.ylabel("Vc/Vo ratio")
plt.xlabel("Time since start of discharge (seconds)")
plt.title("Exp 1c: RC circuit discharging curve - Normalized voltage over time")
#plt.loglog(angular_frequency,ymanual,'g')
plt.text(.5,.5,"Fit parameters")
plt.text(.5,.4,"A = %.4g" %(A))
plt.text(.5,.3,"B = %.4g" %(B))
plt.legend()
# Out:
# 0.03563260634478355
# 0.8441030420497492

# %%
plt.plot(c_fallingTime,c_fallingRatio,'b',marker='o',linewidth=10,label = "Data")
plt.plot(c_fallingTime,ypred,'r',marker='.',linewidth=.1,label = "Least squares fit A*np.exp(-t/B)")
plt.ylabel("Vc/Vo ratio")
plt.xlabel("Time since start of discharge (seconds)")
plt.title("RC circuit discharging curve - Normalized voltage over time")
#plt.loglog(angular_frequency,ymanual,'g')
plt.text(1,.5,"Fit parameters")
plt.text(1,.4,"A = %.4g" %(A))
plt.text(1,.3,"B = %.4g" %(B))
plt.legend()

# %%
def phase_shift_line(w,R,C):
    return np.arctan(-w*R*C)

theory_phase_shift_line = phase_shift_line(angular_frequency,1500,1*10**(-6))


phase_pars, phase_cov = opt.curve_fit(phase_shift_line, angular_frequency, phase, p0=[1,0.00158])

R,C = phase_pars

print(R)
print(C)

phase_pred = phase_shift_line(angular_frequency, R,C)

plt.semilogx(angular_frequency,phase,'b',marker='o',label="Data")
plt.semilogx(angular_frequency,theory_phase_shift_line,'r',marker='x',label="Theoretical Phase Shift Line")
plt.semilogx(angular_frequency,phase_pred,'g',label="Least Squares Fit Line \n Phase shift = arctan(-w*R*C)")
plt.ylabel("RC Phase shift (radians)")
plt.xlabel("Log(Angular frequency (Hz))")
plt.title("Phase shift vs angular frequency - Semilog")
plt.legend()
plt.text(40,-.8,"Fit parameters")
plt.text(40,-.9,"R = 1.055")
plt.text(40,-1,"C = 1.483 * 10^-3")
# Out:
# 1.0549585917241415
# 0.001483275720123185
# Text(40, -1, 'C = 1.483 * 10^-3')

# %%
print(R*C)
# Out:
# 0.0015647944648397671

# %%
#RL Data

RL_Freq = [5,
10,
20,
50,
100,
200,
500,
1000,
2000,
5000,
10000,
20000,
50000,
100000]

RL_Vo = [3.684,
3.685,
3.684,
3.690,
3.682,
3.684,
3.681,
3.685,
3.687,
3.740,
3.763,
3.889,
3.972,
4.067]

RL_VL = [0.022,
0.022,
0.022,
0.025,
0.030,
0.047,
0.106,
0.208,
0.410,
0.996,
1.830,
2.863,
3.69,
3.88]

RL_Phase = [3.708,
6.645,
10.530,
26.020,
42.340,
62.040,
75.530,
80.770,
80.570,
73.030,
59.970,
40.43,
16.65,
6.951]

rl_frequency = np.array(RL_Freq)
rl_Vo = np.array(RL_Vo)
rl_VL = np.array(RL_VL)
rl_phase = np.array(RL_Phase)*3.1415/180

# %%
rl_ratio = rl_VL/rl_Vo

# %%
rl_angular_frequency = 2*3.1415*rl_frequency

# %%
# Simple harmonic motion using acceleration
def given_fit_RL(w, A, tau):                  # inputs: t:time, A:amplitude, B:offset, w:angular frequency, phi:phase
    return A*w*tau/((1 + ((w*tau)**2))**(0.5))   # output: acceleration

rl_start_pars=[.1,.1]
#pars, cov = opt.curve_fit(oscillator_model, tvals-start_time, yvals, p0=start_pars, betainit)
rl_pars, rl_cov = opt.curve_fit(given_fit_RL, rl_angular_frequency, rl_ratio, p0=rl_start_pars)

rl_A,rl_tau = rl_pars
print(rl_tau)
# Out:
# 9.150486656101912e-06

# %%
plt.loglog(rl_angular_frequency,rl_ratio,'b',marker='o')
plt.ylabel("Log(VL/Vo)")
plt.xlabel("Log(Angular frequency)")
plt.title("VL/Vo vs Angular Frequency, loglog plot")
# Out:
# Text(0.5, 1.0, 'VL/Vo vs Angular Frequency, loglog plot')

# %%
rl_ypred = given_fit_RL(rl_angular_frequency, rl_A, rl_tau)
#ymanual = given_fit_RL(rl_angular_frequency, 0.99688, .00158)
# amplitude = .99688, RC = .00158 -- values from Ronnie's fit
print(rl_tau)
print(rl_A)
# Out:
# 9.150486656101912e-06
# 0.9753593556294631

# %%
plt.loglog(rl_angular_frequency,rl_ratio,'b',marker='o',label = "Data")
plt.loglog(rl_angular_frequency,rl_ypred,'r',marker='x',label = "Least Squares Fit /n VL/Vo = A*w*tau/((1 + ((w*tau)**2))**(0.5))")
plt.ylabel("Log(VL/Vo)")
plt.xlabel("Log(Angular frequency)")
plt.title("RL VL/Vo vs Angular Frequency, loglog plot")
#plt.loglog(rl_angular_frequency,'g')
plt.text(100,.20,"Fit parameters")
plt.text(100,.1,"A = .9754")
plt.text(100,.05,"Tau = 9.150 * 10^-6")
plt.legend()

# %%
def phase_shift_line_RL(w,tau):
    return np.arctan(1/(tau*w))
#a = R/w*L
#1/tau = R/L
#1/(tau*w) = R/(w*L)

rl_theory_phase_shift_line = phase_shift_line_RL(rl_angular_frequency,9.150*10**(-6))


#rl_phase_pars, rl_phase_cov = opt.curve_fit(phase_shift_line_RL, rl_angular_frequency, rl_phase, p0=[1,0.00158])

#R,C = phase_pars

#print(R)
#print(C)

rl_theory_phase_shift_line = phase_shift_line_RL(rl_angular_frequency,9.150*10**(-6))

plt.semilogx(rl_angular_frequency,rl_phase,'b',marker='o',label="Data")
plt.semilogx(rl_angular_frequency,rl_theory_phase_shift_line,'r',marker='x',label="Theoretical Phase Shift Line")
#plt.semilogx(angular_frequency,phase_pred,'g',label="Least Squares Fit Line \n Phase shift = arctan(-w*R*C)")
plt.ylabel("Phase shift (radians)")
plt.xlabel("Log(Angular frequency (Hz))")
plt.title("RL Phase shift vs angular frequency - Semilog")
plt.legend()
plt.text(30,1.3,"Theory line generated with:")
plt.text(30,1.2,"Tau = 9.150 * 10^-6")
# Out:
# Text(30, 1.2, 'Tau = 9.150 * 10^-6')
